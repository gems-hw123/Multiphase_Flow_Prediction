# %% [markdown]
# # Precocessing Dataset

# %%
import random
import torch
import numpy as np
import os
import matplotlib.image as mpimg
from torch.utils.data import Dataset, DataLoader, random_split

# %%
def set_seed(seed):
    """
    Use this to set ALL the random seeds to a fixed value and take out any randomness from cuda kernels
    """
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

    torch.backends.cudnn.benchmark = True  ##uses the inbuilt cudnn auto-tuner to find the fastest convolution algorithms. -
    torch.backends.cudnn.enabled   = True

    return True

# %%
class Crop3D:
    def __init__(self, output_size):
        self.output_size = output_size

    def __call__(self, input, output):
        h, w, d = input.shape
        new_h, new_w, new_d = self.output_size
        

        top = np.random.randint(0, h - new_h + 1)
        left = np.random.randint(0, w - new_w + 1)
        front = np.random.randint(0, d - new_d + 1)
        # top = 800
        # left = 1000
        # front = 1000
        
        input = input[top: top + new_h, left: left + new_w, front: front + new_d]
        output = output[top: top + new_h, left: left + new_w, front: front + new_d]
        return input, output
    

class CTDataset(Dataset):
    def __init__(self, base_dir, global_min, global_max,transform=None):
        self.base_dir = base_dir
        self.dry_scan_dirs = [os.path.join(base_dir, d) for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d)) and d.startswith("004_estaillades1_DI")]
        self.exper_dirs = [os.path.join(base_dir, d) for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d)) and d.startswith("032_estaillades1_q01_fw07_us")]
        self.global_min = global_min
        self.global_max = global_max
        self.sample_list = self._create_sample_list()
        self.transform = transform
        
        self.dry_scan_path = self._create_dry_scan_list()
        
    def _create_dry_scan_list(self):
        sub_dirs = self.dry_scan_dirs
        total_time_steps = []

        for sub_dir in sub_dirs:
            time_steps = [os.path.join(sub_dir, f) for f in os.listdir(sub_dir) if os.path.isdir(os.path.join(sub_dir, f))]
            total_time_steps.extend(time_steps)
        total_time_steps.sort()
        
        sample_list = []
        for time_step in total_time_steps:
            for i in range(1600):
                formatted_number = f"{(i+1):04d}"
                img_path = os.path.join(time_step, f'004_estaillades1_DI_{formatted_number}.rec.16bit.tif')
                if os.path.exists(img_path):
                    sample_list.append(img_path)
        return sample_list
        
    def _create_sample_list(self, dry = False):
        sample_list = []
        
        if not dry:
            sub_dirs = self.exper_dirs
            total_time_steps = []
            
            for sub_dir in sub_dirs:
                time_steps = [os.path.join(sub_dir, f) for f in os.listdir(sub_dir) if os.path.isdir(os.path.join(sub_dir, f))]
                total_time_steps.extend(time_steps)
            total_time_steps.sort()
        
#             for time_step in total_time_steps:
#                 folder_name = os.path.basename(time_step)[-5:]
#                 for i in range(1600):
#                     formatted_number = f"{(i+1):04d}"
#                     img_path = os.path.join(time_step, f'032_estaillades1_q01_fw07_us_{folder_name}_{formatted_number}.rec.16bit.tif')
#                     if os.path.exists(img_path):
#                         sample_list.append(img_path
        
#             for time_step in total_time_steps:
#                 for i in range(1600):
#                     formatted_number = f"{(i+1):04d}"
#                     img_path = os.path.join(time_step, f'004_estaillades1_DI_{formatted_number}.rec.16bit.tif')
#                     if os.path.exists(img_path):
#                         sample_list.append(img_path)
            
        return total_time_steps

    def __len__(self):
        return len(self.sample_list)

    def preprocessing(self, idx):
        sample_path = self.sample_list[idx]
#         dry_scan_path = self.dry_scan_path
#         print(dry_scan_path)
        
        img = np.zeros((1600,2016,2016))
#         dry_scan = np.zeros((1600,2016,2016))
        
        folder_name_input = os.path.basename(sample_path)[-5:]
#         folder_name_output = os.path.basename(output_path)[-5:]
        for i in range(1600):
            formatted_number = f"{(i+1):04d}"
            img_path = os.path.join(sample_path, f'032_estaillades1_q01_fw07_us_{folder_name_input}_{formatted_number}.rec.16bit.tif')
#             output_one_channel_path = os.path.join(output_path, f'032_estaillades1_q01_fw07_us_{folder_name_output}_{formatted_number}.rec.16bit.tif')
#             dry_scan_one_channel_path = dry_scan_path[i]
            if os.path.exists(img_path):
                img_one_channel = mpimg.imread(img_path)
                img_one_channel_normalized = (img_one_channel - self.global_min) / (self.global_max - self.global_min)
                img[i,:,:] = img_one_channel_normalized
                
#                 output_scan_one_channel = mpimg.imread(output_one_channel_path)
#                 output_scan_one_channel_normalized = (output_scan_one_channel- self.global_min) / (self.global_max - self.global_min)
#                 output[i,:,:] = output_scan_one_channel_normalized
                
#                 dry_scan_one_channel = mpimg.imread(dry_scan_one_channel_path)
#                 dry_scan_one_channel_normalized = (dry_scan_one_channel - self.global_min) / (self.global_max - self.global_min)
#                 dry_scan[i,:,:] = dry_scan_one_channel_normalized
                
        print(img_path)
        img = torch.from_numpy(img).float()
#         dry_scan = torch.from_numpy(dry_scan).float()
        print("the img shape:",img.shape)
        torch.save(img, f'/rds/general/user/hw123/ephemeral/dataset/wet_scan/time_step_{folder_name_input}.pt')
        print(f"time_step_{folder_name_input} is saved")
        
        
        
#         img = mpimg.imread(img_path)
#         img_normalized = (img - self.global_min) / (self.global_max - self.global_min)
#         img_normalized = torch.tensor(img_normalized, dtype=torch.float32)
        
#         if self.transform:
#             img, output = self.transform(img, output)

# %%
## Cacluate the max and min
def estimate_global_min_max(base_dir, num_samples = 4, num_slices = 100):
    sub_dirs = [os.path.join(base_dir, d) for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir,d))]
    sampled_dirs = random.sample(sub_dirs, min(num_samples, len(sub_dirs)))
    
    print(sampled_dirs)
    global_min = float('inf')
    global_max = float('-inf')

    for sub_dir in sampled_dirs:
        folder_name = os.path.basename(sub_dir)[-5:]
        sampled_slices = random.sample(range(1600), num_slices)
        
        for i in sampled_slices:
            formatted_number = f"{(i+1):04d}"
            img_path = os.path.join(sub_dir, f'032_estaillades1_q01_fw07_us_{folder_name}_{formatted_number}.rec.16bit.tif')
            
            if os.path.exists(img_path):
                img = mpimg.imread(img_path)
                global_min = min(global_min, img.min())
                global_max = max(global_max, img.max())
    
    return global_min, global_max

# %%
base_dir = f'../data_set/IRP_porescale_AI/032_estaillades1_q01_fw07_us'
set_seed(42)
global_min, global_max = estimate_global_min_max(base_dir)
print(f"Global min: {global_min}, Global max: {global_max}")
# Out:
# ['../data_set/IRP_porescale_AI/032_estaillades1_q01_fw07_us/rec_16bit_phase_00019', '../data_set/IRP_porescale_AI/032_estaillades1_q01_fw07_us/rec_16bit_phase_00004', '../data_set/IRP_porescale_AI/032_estaillades1_q01_fw07_us/rec_16bit_phase_00009', '../data_set/IRP_porescale_AI/032_estaillades1_q01_fw07_us/rec_16bit_phase_00026']
# Global min: 0, Global max: 65535

# %%
base_dir = f'../data_set/IRP_porescale_AI'
dataset = CTDataset(base_dir=base_dir,global_max=global_max,global_min=global_min)
len(dataset)
# Out:
# 30

# %%
for i in range(len(dataset)):
    dataset.preprocessing(i)

# %%
img = torch.load(f'/rds/general/user/hw123/ephemeral/dataset/wet_scan/time_step_00030.pt')
img.shape,img
# Out:
# (torch.Size([1600, 2016, 2016]),
#  tensor([[[0.3121, 0.3144, 0.3094,  ..., 0.3037, 0.2889, 0.2913],
#           [0.2910, 0.3065, 0.2989,  ..., 0.2914, 0.2905, 0.2998],
#           [0.2976, 0.3067, 0.2987,  ..., 0.2964, 0.2841, 0.2918],
#           ...,
#           [0.2940, 0.3015, 0.2916,  ..., 0.3165, 0.3387, 0.2903],
#           [0.2888, 0.3017, 0.2944,  ..., 0.2994, 0.3283, 0.3230],
#           [0.2966, 0.3093, 0.3048,  ..., 0.3074, 0.3006, 0.3048]],
#
#          [[0.2933, 0.2940, 0.3025,  ..., 0.2984, 0.2974, 0.3012],
#           [0.2853, 0.3066, 0.3144,  ..., 0.3080, 0.2985, 0.3064],
#           [0.2762, 0.2868, 0.3096,  ..., 0.3091, 0.2837, 0.3095],
#           ...,
#           [0.3116, 0.3083, 0.3129,  ..., 0.3051, 0.3053, 0.2924],
#           [0.3025, 0.3097, 0.3120,  ..., 0.3138, 0.3142, 0.2966],
#           [0.3119, 0.3078, 0.2919,  ..., 0.3177, 0.3140, 0.3215]],
#
#          [[0.2718, 0.2832, 0.3159,  ..., 0.3145, 0.3128, 0.2996],
#           [0.2872, 0.2880, 0.3038,  ..., 0.3100, 0.2972, 0.2799],
#           [0.3008, 0.2957, 0.3021,  ..., 0.3017, 0.2852, 0.2839],
#           ...,
#           [0.3227, 0.3142, 0.3059,  ..., 0.3228, 0.2979, 0.2818],
#           [0.2989, 0.3063, 0.2996,  ..., 0.3190, 0.3211, 0.2847],
#           [0.2904, 0.3071, 0.2737,  ..., 0.2947, 0.3230, 0.3059]],
#
#          ...,
#
#          [[0.2799, 0.3046, 0.3012,  ..., 0.3211, 0.3055, 0.2932],
#           [0.2893, 0.3135, 0.3233,  ..., 0.3127, 0.2826, 0.3003],
#           [0.2832, 0.3085, 0.3316,  ..., 0.2782, 0.2883, 0.3028],
#           ...,
#           [0.3140, 0.2849, 0.2840,  ..., 0.2958, 0.3137, 0.2904],
#           [0.2944, 0.2803, 0.2843,  ..., 0.2623, 0.3033, 0.3050],
#           [0.2909, 0.2724, 0.2729,  ..., 0.2729, 0.2773, 0.2858]],
#
#          [[0.3053, 0.3066, 0.3244,  ..., 0.3192, 0.3080, 0.2979],
#           [0.3095, 0.3118, 0.3305,  ..., 0.3090, 0.2931, 0.2945],
#           [0.3007, 0.3085, 0.3317,  ..., 0.2908, 0.2961, 0.2895],
#           ...,
#           [0.3026, 0.2842, 0.2957,  ..., 0.2969, 0.3096, 0.2812],
#           [0.2915, 0.2807, 0.2869,  ..., 0.2666, 0.3033, 0.2879],
#           [0.2837, 0.2759, 0.2942,  ..., 0.2766, 0.2984, 0.2953]],
#
#          [[0.2980, 0.2781, 0.3125,  ..., 0.3299, 0.3396, 0.3056],
#           [0.3257, 0.2867, 0.2992,  ..., 0.3249, 0.3037, 0.2781],
#           [0.3229, 0.3077, 0.2797,  ..., 0.3071, 0.2952, 0.2785],
#           ...,
#           [0.3311, 0.2912, 0.2941,  ..., 0.3067, 0.2968, 0.2745],
#           [0.3266, 0.2938, 0.3131,  ..., 0.2926, 0.2988, 0.2857],
#           [0.3173, 0.2808, 0.2985,  ..., 0.2889, 0.2929, 0.2828]]]))

# %%
dry = torch.load(f'../data_set/IRP_porescale_tensor/dry_scan/dry_scan.pt')

# %%
dry
# Out:
# tensor([[[0.2600, 0.2712, 0.2880,  ..., 0.2985, 0.3037, 0.2907],
#          [0.2866, 0.2713, 0.2797,  ..., 0.2955, 0.2798, 0.2751],
#          [0.3160, 0.2963, 0.2928,  ..., 0.2678, 0.2712, 0.2769],
#          ...,
#          [0.2999, 0.3286, 0.3283,  ..., 0.2923, 0.2996, 0.2880],
#          [0.3217, 0.3284, 0.2912,  ..., 0.2966, 0.3095, 0.2918],
#          [0.2964, 0.2893, 0.2870,  ..., 0.2951, 0.3130, 0.3215]],
#
#         [[0.2640, 0.2807, 0.2925,  ..., 0.3103, 0.3147, 0.3093],
#          [0.2831, 0.2821, 0.2859,  ..., 0.3004, 0.2840, 0.2728],
#          [0.3056, 0.2986, 0.2973,  ..., 0.2723, 0.2734, 0.2778],
#          ...,
#          [0.3057, 0.2969, 0.3073,  ..., 0.3142, 0.3072, 0.2917],
#          [0.2958, 0.2970, 0.3004,  ..., 0.3153, 0.3226, 0.2978],
#          [0.2883, 0.2952, 0.3036,  ..., 0.2973, 0.3312, 0.3331]],
#
#         [[0.2624, 0.2789, 0.3001,  ..., 0.2951, 0.2884, 0.3064],
#          [0.2843, 0.2847, 0.2913,  ..., 0.2841, 0.2930, 0.3138],
#          [0.2956, 0.2967, 0.2992,  ..., 0.2871, 0.3022, 0.3064],
#          ...,
#          [0.3108, 0.2958, 0.2995,  ..., 0.3090, 0.2964, 0.3047],
#          [0.3029, 0.2998, 0.2973,  ..., 0.3183, 0.3083, 0.3068],
#          [0.2916, 0.2888, 0.2833,  ..., 0.3052, 0.3125, 0.3237]],
#
#         ...,
#
#         [[0.3147, 0.3080, 0.2917,  ..., 0.2856, 0.2887, 0.3012],
#          [0.2980, 0.3049, 0.2901,  ..., 0.2985, 0.3020, 0.2937],
#          [0.3004, 0.3144, 0.2898,  ..., 0.3104, 0.2965, 0.2892],
#          ...,
#          [0.2974, 0.2931, 0.3075,  ..., 0.2544, 0.2820, 0.2993],
#          [0.2903, 0.3083, 0.3142,  ..., 0.2778, 0.2700, 0.2904],
#          [0.3010, 0.3304, 0.3239,  ..., 0.3142, 0.2882, 0.2961]],
#
#         [[0.2925, 0.2975, 0.2985,  ..., 0.2840, 0.2862, 0.2677],
#          [0.3090, 0.2906, 0.3033,  ..., 0.2883, 0.2827, 0.2920],
#          [0.3140, 0.2945, 0.2811,  ..., 0.2771, 0.2931, 0.3032],
#          ...,
#          [0.2840, 0.3041, 0.3098,  ..., 0.2811, 0.2977, 0.2955],
#          [0.2820, 0.3086, 0.3284,  ..., 0.2728, 0.2922, 0.3039],
#          [0.2858, 0.3378, 0.3358,  ..., 0.2992, 0.2913, 0.3045]],
#
#         [[0.2658, 0.2753, 0.3023,  ..., 0.3138, 0.3041, 0.2778],
#          [0.3188, 0.2912, 0.2906,  ..., 0.3044, 0.2760, 0.2819],
#          [0.3105, 0.3172, 0.3049,  ..., 0.2692, 0.2663, 0.2904],
#          ...,
#          [0.2748, 0.2906, 0.3207,  ..., 0.3067, 0.3023, 0.3149],
#          [0.2697, 0.3067, 0.3275,  ..., 0.2893, 0.2942, 0.2982],
#          [0.2786, 0.3219, 0.3066,  ..., 0.3084, 0.2944, 0.3032]]])

# %%
dataset._create_dry_scan_list()
# Out:
# ['../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0001.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0002.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0003.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0004.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0005.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0006.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0007.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0008.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0009.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0010.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0011.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0012.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0013.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0014.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0015.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0016.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0017.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0018.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0019.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0020.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0021.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0022.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0023.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0024.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0025.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0026.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0027.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0028.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0029.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0030.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0031.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0032.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0033.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0034.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0035.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0036.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0037.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0038.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0039.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0040.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0041.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0042.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0043.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0044.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0045.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0046.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0047.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0048.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0049.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0050.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0051.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0052.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0053.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0054.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0055.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0056.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0057.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0058.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0059.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0060.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0061.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0062.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0063.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0064.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0065.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0066.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0067.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0068.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0069.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0070.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0071.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0072.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0073.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0074.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0075.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0076.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0077.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0078.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0079.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0080.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0081.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0082.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0083.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0084.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0085.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0086.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0087.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0088.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0089.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0090.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0091.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0092.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0093.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0094.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0095.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0096.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0097.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0098.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0099.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0100.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0101.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0102.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0103.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0104.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0105.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0106.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0107.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0108.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0109.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0110.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0111.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0112.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0113.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0114.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0115.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0116.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0117.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0118.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0119.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0120.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0121.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0122.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0123.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0124.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0125.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0126.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0127.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0128.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0129.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0130.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0131.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0132.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0133.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0134.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0135.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0136.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0137.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0138.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0139.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0140.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0141.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0142.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0143.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0144.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0145.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0146.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0147.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0148.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0149.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0150.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0151.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0152.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0153.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0154.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0155.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0156.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0157.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0158.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0159.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0160.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0161.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0162.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0163.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0164.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0165.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0166.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0167.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0168.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0169.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0170.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0171.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0172.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0173.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0174.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0175.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0176.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0177.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0178.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0179.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0180.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0181.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0182.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0183.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0184.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0185.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0186.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0187.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0188.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0189.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0190.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0191.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0192.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0193.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0194.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0195.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0196.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0197.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0198.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0199.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0200.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0201.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0202.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0203.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0204.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0205.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0206.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0207.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0208.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0209.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0210.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0211.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0212.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0213.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0214.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0215.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0216.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0217.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0218.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0219.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0220.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0221.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0222.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0223.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0224.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0225.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0226.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0227.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0228.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0229.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0230.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0231.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0232.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0233.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0234.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0235.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0236.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0237.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0238.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0239.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0240.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0241.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0242.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0243.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0244.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0245.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0246.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0247.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0248.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0249.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0250.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0251.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0252.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0253.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0254.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0255.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0256.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0257.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0258.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0259.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0260.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0261.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0262.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0263.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0264.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0265.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0266.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0267.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0268.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0269.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0270.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0271.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0272.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0273.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0274.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0275.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0276.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0277.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0278.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0279.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0280.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0281.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0282.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0283.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0284.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0285.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0286.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0287.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0288.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0289.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0290.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0291.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0292.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0293.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0294.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0295.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0296.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0297.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0298.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0299.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0300.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0301.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0302.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0303.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0304.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0305.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0306.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0307.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0308.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0309.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0310.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0311.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0312.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0313.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0314.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0315.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0316.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0317.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0318.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0319.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0320.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0321.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0322.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0323.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0324.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0325.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0326.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0327.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0328.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0329.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0330.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0331.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0332.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0333.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0334.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0335.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0336.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0337.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0338.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0339.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0340.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0341.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0342.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0343.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0344.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0345.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0346.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0347.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0348.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0349.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0350.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0351.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0352.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0353.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0354.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0355.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0356.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0357.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0358.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0359.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0360.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0361.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0362.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0363.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0364.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0365.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0366.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0367.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0368.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0369.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0370.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0371.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0372.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0373.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0374.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0375.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0376.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0377.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0378.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0379.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0380.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0381.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0382.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0383.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0384.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0385.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0386.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0387.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0388.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0389.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0390.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0391.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0392.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0393.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0394.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0395.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0396.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0397.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0398.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0399.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0400.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0401.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0402.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0403.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0404.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0405.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0406.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0407.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0408.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0409.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0410.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0411.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0412.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0413.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0414.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0415.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0416.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0417.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0418.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0419.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0420.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0421.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0422.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0423.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0424.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0425.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0426.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0427.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0428.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0429.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0430.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0431.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0432.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0433.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0434.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0435.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0436.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0437.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0438.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0439.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0440.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0441.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0442.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0443.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0444.rec.16bit.tif',
# ...
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0853.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0854.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0855.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0856.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0857.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0858.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0859.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0860.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0861.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0862.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0863.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0864.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0865.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0866.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0867.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0868.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0869.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0870.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0871.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0872.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0873.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0874.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0875.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0876.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0877.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0878.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0879.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0880.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0881.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0882.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0883.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0884.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0885.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0886.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0887.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0888.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0889.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0890.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0891.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0892.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0893.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0894.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0895.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0896.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0897.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0898.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0899.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0900.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0901.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0902.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0903.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0904.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0905.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0906.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0907.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0908.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0909.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0910.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0911.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0912.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0913.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0914.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0915.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0916.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0917.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0918.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0919.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0920.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0921.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0922.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0923.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0924.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0925.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0926.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0927.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0928.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0929.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0930.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0931.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0932.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0933.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0934.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0935.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0936.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0937.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0938.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0939.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0940.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0941.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0942.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0943.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0944.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0945.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0946.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0947.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0948.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0949.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0950.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0951.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0952.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0953.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0954.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0955.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0956.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0957.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0958.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0959.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0960.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0961.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0962.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0963.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0964.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0965.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0966.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0967.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0968.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0969.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0970.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0971.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0972.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0973.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0974.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0975.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0976.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0977.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0978.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0979.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0980.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0981.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0982.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0983.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0984.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0985.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0986.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0987.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0988.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0989.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0990.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0991.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0992.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0993.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0994.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0995.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0996.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0997.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0998.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_0999.rec.16bit.tif',
#  '../data_set/IRP_porescale_AI/004_estaillades1_DI/rec_16bit_phase/004_estaillades1_DI_1000.rec.16bit.tif',
#  ...]
